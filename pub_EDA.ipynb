# %% [markdown]
# # DATA DESCRIPTION

# %% [markdown]
# Let’s assume you are on a vacation in the United Kingdom with your friends. For fun, you decided to go to the Pubs nearby for some drinks. Google Map is down because of some issues.
#
# While searching the internet, you came across https://www.getthedata.com/open-pubs. On this website, you found all the pub locations (Specifically Latitude and Longitude info). In order to impress your friends, you decided to create a web application with the data available in your hand.

# %% [markdown]
# - fsa_id: int-Food Standard Agency's ID for this pub.
# - name:string-Name of the pub.
# - address:string-Address fields separated by commas.
# - postcode:string-Postcode of the pub.
# - easting:int
# - northing:int
# - latitude:decimal
# - longitude:decimal
# - local_authority:string-Local authority this pub falls under.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('open_pubs.csv', names=['fsa_id','name','address','postcode','easting','northing','latitude','longitude','local_authority'])

# %%
df.head()
# Out:
#    fsa_id                name  \
# 0      22          Anchor Inn
# 1      36  Ark Bar Restaurant
# 2      74           Black Boy
# 3      75         Black Horse
# 4      76          Black Lion
#
#                                              address  postcode  easting  \
# 0        Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749
# 1  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 3        Lower Street, Stratford St Mary, COLCHESTER   CO7 6JS   622675
# 4                      Lion Road, Glemsford, SUDBURY  CO10 7RF   622675
#
#    northing   latitude longitude local_authority
# 0    234404  51.970379  0.979340         Babergh
# 1    233329  51.958698  1.057832         Babergh
# 2    241316  52.038595  0.729915         Babergh
# 3  -5527598         \N        \N         Babergh
# 4  -5527598         \N        \N         Babergh

# %%
df.shape
# Out:
# (51331, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51331 entries, 0 to 51330
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fsa_id           51331 non-null  int64
#  1   name             51331 non-null  object
#  2   address          51331 non-null  object
#  3   postcode         51331 non-null  object
#  4   easting          51331 non-null  int64
#  5   northing         51331 non-null  int64
#  6   latitude         51331 non-null  object
#  7   longitude        51331 non-null  object
#  8   local_authority  51331 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 3.5+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# fsa_id             0
# name               0
# address            0
# postcode           0
# easting            0
# northing           0
# latitude           0
# longitude          0
# local_authority    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fsa_id', 'name', 'address', 'postcode', 'easting', 'northing',
#        'latitude', 'longitude', 'local_authority'],
#       dtype='object')

# %%
df.longitude.value_counts()
# Out:
# \N           767
# -0.655576     12
# -1.853894     10
# 0.349896       9
# -2.051721      8
#             ...
# -2.734245      1
# -2.735554      1
# -2.733804      1
# -2.735118      1
# -3.050512      1
# Name: longitude, Length: 46807, dtype: int64

# %%
df.latitude.value_counts()
# Out:
# \N           767
# 51.310946     10
# 52.896164     10
# 53.178189      9
# 55.318954      8
#             ...
# 53.369771      1
# 53.390799      1
# 53.371238      1
# 53.361078      1
# 53.076638      1
# Name: latitude, Length: 46810, dtype: int64

# %%
df.replace('\\N',np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# fsa_id               0
# name                 0
# address              0
# postcode             0
# easting              0
# northing             0
# latitude           767
# longitude          767
# local_authority      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# fsa_id             0
# name               0
# address            0
# postcode           0
# easting            0
# northing           0
# latitude           0
# longitude          0
# local_authority    0
# dtype: int64

# %%
df.latitude = df.latitude.astype(float)

# %%
df.longitude=df.longitude.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50564 entries, 0 to 51330
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fsa_id           50564 non-null  int64
#  1   name             50564 non-null  object
#  2   address          50564 non-null  object
#  3   postcode         50564 non-null  object
#  4   easting          50564 non-null  int64
#  5   northing         50564 non-null  int64
#  6   latitude         50564 non-null  float64
#  7   longitude        50564 non-null  float64
#  8   local_authority  50564 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 3.9+ MB

# %%
df.head()
# Out:
#    fsa_id                name  \
# 0      22          Anchor Inn
# 1      36  Ark Bar Restaurant
# 2      74           Black Boy
# 5      97        Brewers Arms
# 6     102        Bristol Arms
#
#                                              address  postcode  easting  \
# 0        Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749
# 1  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 5  The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 6                     Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
#
#    northing   latitude  longitude local_authority
# 0    234404  51.970379   0.979340         Babergh
# 1    233329  51.958698   1.057832         Babergh
# 2    241316  52.038595   0.729915         Babergh
# 5    240655  52.028694   0.895650         Babergh
# 6    233550  51.955042   1.267642         Babergh

# %%
df.local_authority.value_counts()
# Out:
# County Durham         680
# Leeds                 611
# Cornwall              557
# Wiltshire             544
# Kirklees              524
#                      ...
# Orkney Islands         15
# East Renfrewshire      12
# Na h-Eileanan Siar     11
# Isles of Scilly        10
# West Lothian            2
# Name: local_authority, Length: 360, dtype: int64

# %%
df.postcode.value_counts()
# Out:
# GU24 0NY    12
# L2 6RE      11
# ST14 8BD    10
# CA1 1RP      9
# PE25 1NJ     9
#             ..
# LA1 1RD      1
# LA4 4TH      1
# LA1 4XQ      1
# LA1 4SA      1
# LL11 5EA     1
# Name: postcode, Length: 45231, dtype: int64

# %%
df.name.value_counts()
# Out:
# The Red Lion                      193
# The Royal Oak                     170
# Red Lion                          130
# The Crown Inn                     112
# Royal Oak                         102
#                                  ...
# Old Hall Inn                        1
# Morecambe Golf Club - Catering      1
# Morecambe Golf Club                 1
# Morecambe Cricket Club              1
# Y Tai                               1
# Name: name, Length: 35809, dtype: int64

# %%
df.local_authority.value_counts().head(10).sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.head(50)
# Out:
#     fsa_id                                 name  \
# 0       22                           Anchor Inn
# 1       36                   Ark Bar Restaurant
# 2       74                            Black Boy
# 5       97                         Brewers Arms
# 6      102                         Bristol Arms
# 7      122                      Caffeine Lounge
# 9      152                   Chestnut Tree Farm
# 10     172                          Cock & Bell
# 11     254                      Eight Bells Inn
# 12     273                        Finezza pizza
# 13     287                       Fox and Hounds
# 14     300                Glemsford Social Club
# 15     310   Grover and Allen - J D Wetherspoon
# 16     324                      Hare And Hounds
# 17     325                      Hare and Hounds
# 18     345  Hintlesham & Chattisham Social Club
# 19     415                           Kings Head
# 20     416                        Kins Head Inn
# 21     448                     Long Melford Inn
# 22     459                          Maldon Grey
# 24     513                  North Street Tavern
# 25     533               Oyster Reach Beafeater
# 28     589             Royal Harwich Yacht Club
# 29     591                            Royal Oak
# 30     619                     Shotley Vineyard
# 31     622                             Silkworm
# 32     626                            Six bells
# 33     692               Sudbury Institute Club
# 34     702                    Suffolk Chefs Ltd
# 35     734                       The Anchor Inn
# 36     735              The Angel Glemsford Ltd
# 38     743                        The Bay Horse
# 39     744                           The Beagle
# 40     750                      The Brewery Tap
# 41     755                        The Brook Inn
# 42     757                             The Bull
# 43     759                         The Bush Inn
# 44     760                    The Butt & Oyster
# 46     766                   The Cock Horse Inn
# 47     767                         The Cock Inn
# 48     768                         The Cock Inn
# 49     769                         The Cock Inn
# 50     773                  The Comfortable Cow
# 51     774                            The Crown
# 52     775                        The Crown Inn
# 54     782          The Edwardstone White Horse
# 55     783                       The Five Bells
# 56     793                   The Gardeners Arms
# 57     794                           The George
# 59     796            The George and Dragon Inn
#
#                                               address  postcode  easting  \
# 0         Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749
# 1   Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2   The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 5   The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 6                      Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
# 7   14 Borehamgate Shopping Precinct, King Street,...  CO10 2ED   587527
# 9          3 Donald Mackintosh Way, Pinewood, IPSWICH   IP8 3LQ   612862
# 10  Cock And Bell, Hall Street, Long Melford, SUDBURY  CO10 9JR   586264
# 11  Eight Bells Public House, 90-92 Angel Street, ...   IP7 5DD   602934
# 12  Eight Bells Public House, 90-92 Angel Street, ...   IP7 5DD   602934
# 13    Fox and Hounds., Church Street, Groton, SUDBURY  CO10 5ED   595967
# 14      25-27 Hunts Hill, Glemsford, SUDBURY, Suffolk  CO10 7RP   582842
# 15  The Grover and Allen, 67-70 North Street, SUDB...  CO10 1RF   587393
# 16  Hare and Hounds, Heath Road, East Bergholt, CO...   CO7 6RL   607633
# 17  Hare and Hounds PH, Harrow Street, Leavenheath...   CO6 4PW   595452
# 18  Community Centre, Timperleys, Hintlesham, IPSWICH   IP8 3PS   608560
# 19                132 High Street, Bildeston, IPSWICH   IP7 7ED   599244
# 20             115 Bures Road, Great Cornard, SUDBURY  CO10 0JE   588383
# 21  The Long Melford Inn, Station Road, Long Melfo...  CO10 9HN   585923
# 22                  Cats Lane, Great Cornard, SUDBURY  CO10 2RZ   588540
# 24                  66 North Street, SUDBURY, Suffolk  CO10 1RE   587307
# 25  Oyster Reach Beefeater, Bourne Hill, Wherstead...   IP2 8ND   616178
# 28              Cat House Lane, Woolverstone, IPSWICH   IP9 1AT   619439
# 29  Royal Oak, East End Lane, East Bergholt, COLCH...   CO7 6XA   609998
# 30                      Frogs Alley, Shotley, IPSWICH   IP9 1FB   623884
# 31         Weavers Tap, East Street, SUDBURY, Suffolk  CO10 2HX   587489
# 32  Six Bells Inn, Church Road, Felsham, BURY ST E...  IP30 0PJ   594678
# 33                  54 Station Road, SUDBURY, Suffolk  CO10 2SP   587352
# 34         White Hart, Broad Street, Boxford, SUDBURY  CO10 5DX   596289
# 35  26 Court Street, Nayland with Wissington, COLC...   CO6 4JL   597415
# 36     Angel Inn, Egremont Street, Glemsford, SUDBURY  CO10 7SA   582888
# 38               61-65 Melford Road, SUDBURY, Suffolk  CO10 1JS   587176
# 39                 Hadleigh Road, Sproughton, IPSWICH   IP8 3AR   612459
# 40                      East Street, SUDBURY, Suffolk  CO10 2TP   587528
# 41             241 Bures Road, Great Cornard, SUDBURY  CO10 0JQ   588555
# 42    The Bull Inn, The Street, Brantham, MANNINGTREE  CO11 1PN   612239
# 43   The Bush, The Street, Shimpling, BURY ST EDMUNDS  IP29 4HU   587401
# 44  Butt and Oyster Inn, Pin Mill Road, Chelmondis...   IP9 1JW   620710
# 46     The Cock Inn, Church Street, Lavenham, SUDBURY  CO10 9SA   591368
# 47                89 George Street, Hadleigh, IPSWICH   IP7 5BP   602983
# 48               Polstead Green, Polstead, COLCHESTER   CO6 5AL   599283
# 49     The Cock, Lavenham Road, Brent Eleigh, SUDBURY  CO10 9PB   594098
# 50  Unit 3, The Pied Cow, 12 King Street, SUDBURY,...  CO10 2EB   587512
# 51                        High Street, Acton, SUDBURY  CO10 0AT   589436
# 52  Crown Inn, Cattawade Street, Brantham, MANNING...  CO11 1RE   610209
# 54  White Horse Inn, Mill Green, Edwardstone, SUDBURY  CO10 5PX   595149
# 55              63 Bures Road, Great Cornard, SUDBURY  CO10 0HU   588333
# 56  Gardeners Arms, Manningtree Road, Stutton, IPS...   IP9 2TG   614020
# 57                  52 High Street, Hadleigh, IPSWICH   IP7 5AL   602704
# 59  The George and Dragon Public House, Hall Stree...  CO10 9JA   586282
#
#     northing   latitude  longitude local_authority
# 0     234404  51.970379   0.979340         Babergh
# 1     233329  51.958698   1.057832         Babergh
# 2     241316  52.038595   0.729915         Babergh
# 5     240655  52.028694   0.895650         Babergh
# 6     233550  51.955042   1.267642         Babergh
# 7     241247  52.037903   0.732687         Babergh
# 9     242887  52.043494   1.102543         Babergh
# 10    245558  52.077053   0.716643         Babergh
# 11    242836  52.046763   0.957949         Babergh
# 12    242836  52.046763   0.957949         Babergh
# 13    241546  52.037682   0.855749         Babergh
# 14    247729  52.097693   0.667931         Babergh
# 15    241511  52.040323   0.730880         Babergh
# 16    235423  51.978451   1.021879         Babergh
# 17    237417  52.000783   0.845896         Babergh
# 18    243367  52.049435   1.040192         Babergh
# 19    249527  52.108170   0.908123         Babergh
# 20    239975  52.026188   0.744452         Babergh
# 21    244321  52.066051   0.710999         Babergh
# 22    241341  52.038399   0.747488         Babergh
# 24    241626  52.041382   0.729689         Babergh
# 25    241872  52.033095   1.150156         Babergh
# 28    239042  52.006409   1.195817         Babergh
# 29    235171  51.975311   1.056110         Babergh
# 30    236057  51.977853   1.258526         Babergh
# 31    241462  52.039848   0.732251         Babergh
# 32    257067  52.177498   0.845845     Mid Suffolk
# 33    241190  52.037454   0.730107         Babergh
# 34    240564  52.028752   0.859875         Babergh
# 35    234054  51.969882   0.872520         Babergh
# 36    247368  52.094425   0.668408         Babergh
# 38    241782  52.042830   0.727868         Babergh
# 39    243689  52.050854   1.097165         Babergh
# 40    241500  52.040169   0.732839         Babergh
# 41    239362  52.020633   0.746619         Babergh
# 42    234481  51.968265   1.088246         Babergh
# 43    253020  52.143674   0.737318         Babergh
# 44    237977  51.996349   1.213618         Babergh
# 46    248958  52.105839   0.792936         Babergh
# 47    242705  52.045565   0.958589         Babergh
# 48    238286  52.007221   0.902132         Babergh
# 49    247842  52.094870   0.832123         Babergh
# 50    241324  52.038603   0.732496         Babergh
# 51    244890  52.069965   0.762503         Babergh
# 52    233104  51.956673   1.057912         Babergh
# 54    242672  52.048066   0.844481         Babergh
# 55    240302  52.029137   0.743898         Babergh
# 56    234535  51.968075   1.114180         Babergh
# 57    242467  52.043532   0.954382         Babergh
# 59    245457  52.076134   0.716836         Babergh

# %%
pip install folium
# Out:
# Collecting folium
#   Using cached folium-0.14.0-py2.py3-none-any.whl (102 kB)
# Requirement already satisfied: requests in c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages (from folium) (1.23.2)
# Collecting branca>=0.6.0
#   Using cached branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2022.6.15)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -reamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -reamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -reamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -reamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -reamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -reamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -reamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -reamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo x1 yoga\appdata\local\programs\python\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: C:\Users\LENOVO X1 YOGA\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip

# %%
import folium

# %%
import folium

# Create a map object with a starting location and zoom level
map = folium.Map(location=[52.076134,0.954382], zoom_start=10)

# Add a marker to the map
folium.Marker(location=[52.076134, 0.954382], tooltip='Open Pub', popup='Anchor Inn').add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac471d8553dbcff40294df4d1eeadc5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac471d8553dbcff40294df4d1eeadc5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac471d8553dbcff40294df4d1eeadc5d = L.map(
#                 &quot;map_ac471d8553dbcff40294df4d1eeadc5d&quot;,
#                 {
#                     center: [52.076134, 0.954382],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81d7740f7e25b2e76b8c186083649b82 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac471d8553dbcff40294df4d1eeadc5d);
#
#
#             var marker_c7c27b6582667e4c9a1748dc9ceb3d12 = L.marker(
#                 [52.076134, 0.954382],
#                 {}
#             ).addTo(map_ac471d8553dbcff40294df4d1eeadc5d);
#
#
#         var popup_bf8fe149f59719e4c08982b5dd770a64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf8a21f63cea088f25e031be3976c69d = $(`&lt;div id=&quot;html_bf8a21f63cea088f25e031be3976c69d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anchor Inn&lt;/div&gt;`)[0];
#                 popup_bf8fe149f59719e4c08982b5dd770a64.setContent(html_bf8a21f63cea088f25e031be3976c69d);
#
#
#
#         marker_c7c27b6582667e4c9a1748dc9ceb3d12.bindPopup(popup_bf8fe149f59719e4c08982b5dd770a64)
#         ;
#
#
#
#
#             marker_c7c27b6582667e4c9a1748dc9ceb3d12.bindTooltip(
#                 `&lt;div&gt;
#                      Open Pub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.to_csv("resources\data\pub_cleaned.csv", index=False)

# %%
data
# Out:
#        fsa_id                                      name  \
# 0          22                                Anchor Inn
# 1          36                        Ark Bar Restaurant
# 2          74                                 Black Boy
# 3          97                              Brewers Arms
# 4         102                              Bristol Arms
# ...       ...                                       ...
# 50559  597119  Wrexham & District War Memorial Club Ltd
# 50560  597127                 Wrexham Lager Social Club
# 50561  597130         Wrexham Rail Sports & Social Club
# 50562  597131                        Wrexham Rugby Club
# 50563  597137                                     Y Tai
#
#                                                  address  postcode  easting  \
# 0            Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749
# 1      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 3      The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 4                         Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
# ...                                                  ...       ...      ...
# 50559  Wrexham War Memorial Club Farndon Street, Wrex...  LL13 8DE   333909
# 50560                 1 - 3 Union Road, Wrexham, Wrexham  LL13 7SR   333028
# 50561  Sports And Social Club, 44 Brook Street, Wrexh...  LL13 7LU   333259
# 50562  Wrexham Rugby Club Bryn Estyn Road, Wrexham, W...  LL13 9TY   335808
# 50563       Y Tai Railway Road, Brymbo, Wrexham, Wrexham  LL11 5EA   329721
#
#        northing   latitude  longitude local_authority
# 0        234404  51.970379   0.979340         Babergh
# 1        233329  51.958698   1.057832         Babergh
# 2        241316  52.038595   0.729915         Babergh
# 3        240655  52.028694   0.895650         Babergh
# 4        233550  51.955042   1.267642         Babergh
# ...         ...        ...        ...             ...
# 50559    350438  53.047100  -2.987319         Wrexham
# 50560    350563  53.048123  -3.000485         Wrexham
# 50561    350213  53.044998  -2.996966         Wrexham
# 50562    351078  53.053094  -2.959124         Wrexham
# 50563    353785  53.076638  -3.050512         Wrexham
#
# [50564 rows x 9 columns]
